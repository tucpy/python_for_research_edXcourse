# %%
text = "This is my test text. We 're keeping this text short to keep things manageable."

def count_words(text):
    '''
    Count the number of times each word occur in the text
    '''
    # change all words to lower case
    text = text.lower()
    # skip semicolon, colon, double quotes...
    skips = [".",",",";",":","'", '"']
    for ch in skips:
        text = text.replace(ch, "")

    # create an empty dictionary for words
    word_counts = {}
    # iterate each word through the list
    for word in text.split(" "):
        # known word
        if word in word_counts:
            word_counts[word] += 1
        else:
            word_counts[word] = 1
    return word_counts

print(count_words(text))

# Use function Counter from Module collections
from collections import Counter
def count_words_fast(text):
    '''
    Count the number of times each word occur in the text
    '''
    text = text.lower()
    skips = [".",",",";",":","'", '"']
    for ch in skips:
        text = text.replace(ch, "")

    word_counts = Counter(text.split(" "))
    return word_counts

print(count_words_fast(text))

#check if 2 function give the same result? Identical object
a= count_words(text) == count_words_fast(text)
print(a)

print(count_words("This comprehension check is to check for comprehension."))
b = len(count_words("This comprehension check is to check for comprehension."))
print(b)

# false because this 2 different objects
print(count_words(text) is count_words_fast(text))

# Reading a book from a file

def read_book(title_path):
    '''
    Read a book and return it as a string
    '''
    with open(title_path,"r", encoding= "utf8") as current_file:
        text = current_file.read()
        text = text.replace("\n", "").replace("\r","")
    return text


text = read_book ("/Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books_EngFr/English/shakespeare/Romeo and Juliet.txt")
print(len(text)) # see how many characters

#Find location of a sentence (index)
ind = text.find("What's in a name?")
print(ind)

#Get the text from that location
sample_text = text[ind: ind + 1000]
print(sample_text)

def word_stats(word_counts):
    """return number of unique words and word frequencies"""
    num_unique = len(word_counts)
    counts = word_counts.values()
    return (num_unique, counts)

word_counts = count_words(text)
(num_unique, counts) = word_stats(word_counts)

print(num_unique, sum(counts))

text = read_book("/Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books_GerPort/German/shakespeare/Romeo und Julia.txt")
word_counts = count_words(text)
(num_unique, counts) = word_stats(word_counts)
print(num_unique, sum(counts))
# contain 7527 words, in length 20311 


'''
Reading multiple files
'''
# use os module to read directories
import os
book_dir =("/Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books")

# need to delete .DS_Store hidden file in the Book directory, otherwise it will throw an error
# open Termial, type this find /path/to-folder \( -name '.DS_Store' \) -delete
# find /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books \( -name '.DS_Store' \) -delete

print(os.listdir(book_dir))

import pandas as pd 
stats = pd.DataFrame(columns = ("language", "author", "title", "length", "unique"))
title_num = 1 

for language in os.listdir(book_dir):
    for author in os.listdir(book_dir + "/" + language):
        for title in os.listdir(book_dir + "/" + language + "/" + author):
            inputfile = book_dir + "/" + language + "/" + author + "/" + title
            print(inputfile)
            text = read_book(inputfile)
            (num_unique, counts) = word_stats(count_words(text))
            # store data
            stats.loc[title_num] = language, author.capitalize(), title.replace(".txt",""), sum(counts), num_unique
            title_num += 1

print (stats)
print(stats.head())
print(stats.tail())




'''
Intro to Pandas (panel data)
a library that provides additional data structure and data analysis functionalities.
useful for manipulating numerical tables and time series data
'''
import pandas as pd 
table = pd.DataFrame(columns = ("name","age"))
# row 1 of table
table.loc[1] = "James", 22
table.loc[2] = "Jess", 32
print(table)
print(table.columns)


'''
Use matplotlib.pyplot to plot the book length and unique word statistics 
'''
import matplotlib.pyplot as plt
plt.plot(stats.length, stats.unique,"bo")
plt.loglog(stats.length, stats.unique,"bo")

#stats[stats.language = "English"]
# Out:
# {'this': 2, 'is': 1, 'my': 1, 'test': 1, 'text': 2, 'we': 1, 're': 1, 'keeping': 1, 'short': 1, 'to': 1, 'keep': 1, 'things': 1, 'manageable': 1}
# Counter({'this': 2, 'text': 2, 'is': 1, 'my': 1, 'test': 1, 'we': 1, 're': 1, 'keeping': 1, 'short': 1, 'to': 1, 'keep': 1, 'things': 1, 'manageable': 1})
# True
# {'this': 1, 'comprehension': 2, 'check': 2, 'is': 1, 'to': 1, 'for': 1}
# 6
# False
# 169275
# 42757
# What's in a name? That which we call a rose    By any other name would smell as sweet.    So Romeo would, were he not Romeo call'd,    Retain that dear perfection which he owes    Without that title. Romeo, doff thy name;    And for that name, which is no part of thee,    Take all myself.  Rom. I take thee at thy word.    Call me but love, and I'll be new baptiz'd;    Henceforth I never will be Romeo.  Jul. What man art thou that, thus bescreen'd in night,    So stumblest on my counsel?  Rom. By a name    I know not how to tell thee who I am.    My name, dear saint, is hateful to myself,    Because it is an enemy to thee.    Had I it written, I would tear the word.  Jul. My ears have yet not drunk a hundred words    Of that tongue's utterance, yet I know the sound.    Art thou not Romeo, and a Montague?  Rom. Neither, fair saint, if either thee dislike.  Jul. How cam'st thou hither, tell me, and wherefore?    The orchard walls are high and hard to climb,    And the place death, conside
# 5118 40776
# 7527 20311
# ['English', 'French', 'German', 'Portuguese']
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/English/shakespeare/A Midsummer Night's Dream.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/English/shakespeare/Hamlet.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/English/shakespeare/Macbeth.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/English/shakespeare/Othello.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/English/shakespeare/Richard III.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/English/shakespeare/Romeo and Juliet.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/English/shakespeare/The Merchant of Venice.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/French/chevalier/L'åle de sable.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/French/chevalier/L'enfer et le paradis de l'autre monde.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/French/chevalier/La capitaine.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/French/chevalier/La fille des indiens rouges.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/French/chevalier/La fille du pirate.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/French/chevalier/Le chasseur noir.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/French/chevalier/Les derniers Iroquois.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/French/de Maupassant/Boule de Suif.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/French/de Maupassant/Claire de Lune.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/French/de Maupassant/Contes de la Becasse.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/French/de Maupassant/L'inutile beautÇ.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/French/de Maupassant/La Main Gauche.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/French/de Maupassant/La Maison Tellier.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/French/de Maupassant/La petite roque.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/French/de Maupassant/Le Horla.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/French/de Maupassant/Œuvres complètes de Guy de Maupassant.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/French/diderot/Ceci n'est pas un conte.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/French/diderot/Entretien d'un päre avec ses enfants.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/French/diderot/L'oiseau blanc.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/French/diderot/Les deux amis de Bourbonne.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/French/diderot/Regrets sur ma vieille robe de chambre.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/French/sand/cora.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/French/sand/Jacques le fataliste et son maåtre.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/French/sand/L' Orco.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/French/sand/La Coupe; Lupo Liverani; Le Toast; Garnier; Le Contrebandier; La Ràverie Ö Paris.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/French/sand/La Marquise.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/French/sand/Le Piccinino.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/French/sand/Le poâme de Myrza.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/French/sand/Mattea.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/French/sand/Metella.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/French/sand/Oeuvres illustrÇes de George Sand.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/French/sand/Pauline.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/German/lessing/der freigeist.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/German/lessing/der junge gelehrte.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/German/lessing/die juden.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/German/lessing/emilia galotti.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/German/lessing/hamburgische dramaturgie.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/German/lessing/minna von barnhelm.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/German/lessing/miss sara sampson.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/German/lessing/philotas.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/German/raimund/Das MÑdchen aus der Feenwelt.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/German/raimund/Der Alpenkînig und der Menschenfeind.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/German/raimund/Der Barometermacher auf der Zauberinsel.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/German/raimund/Der Diamant des Geisterkînigs.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/German/raimund/Der Verschwender.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/German/raimund/Die gefesselte Phantasie.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/German/raimund/Die unheilbringende Krone.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/German/raimund/Moisasurs Zauberfluch.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/German/schiller/Der Neffe als Onkel.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/German/schiller/Der Parasit, oder die Kunst, sein GlÅck zu machen.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/German/schiller/die braut von messina.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/German/schiller/Die Huldigung der KÅnste.txt
# /Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_3/Books/German/schiller/
# 83   Portuguese         Branco                     Estrellas Prop°cias
# 84   Portuguese         Branco                    Lagrimas Abenáoadas
# 85   Portuguese         Branco                   Livro de Consolação
# 86   Portuguese         Branco                         O Olho de Vidro
# 87   Portuguese         Branco                    O que fazem mulheres
# 88   Portuguese         Branco                              O Regicida
# 89   Portuguese         Branco                   Scenas Contemporaneas
# 90   Portuguese          Dinis             A Morgadinha dos Cannaviaes
# 91   Portuguese          Dinis            Os fidalgos da Casa Mourisca
# 92   Portuguese          Dinis                     Uma fam°lia ingleza
# 93   Portuguese        Queir¢s                    A Cidade e as Serras
# 94   Portuguese        Queir¢s   A correspondància de Fradique Mendes
# 95   Portuguese        Queir¢s              A Illustre Casa de Ramires
# 96   Portuguese        Queir¢s                              A Rel°quia
# 97   Portuguese        Queir¢s                    Cartas de Inglaterra
# 98   Portuguese        Queir¢s                  O crime do padre Amaro
# 99   Portuguese        Queir¢s                              O Mandarim
# 100  Portuguese        Queir¢s                         O Primo Bazilio
# 101  Portuguese        Queir¢s                                Os Maias
# 102  Portuguese    Shakespeare                                  Hamlet
#
#      length unique
# 1     16103   4345
# 2     28551   6776
# 3     16874   4780
# 4     26590   5898
# 5     48315   5449
# 6     40776   5118
# 7     20949   4978
# 8     73801  18989
# 9     40827  10831
# 10    46306  13083
# 11    66621  17875
# 12    52519  14649
# 13    51341  12945
# 14    55565  15583
# 15    35905  10725
# 16    25975   8076
# 17    34723  10210
# 18    37840  10781
# 19    33481   9983
# 20    43685  12305
# 21    40688  10890
# 22    41485  11091
# 23    54772  15028
# 24    10938   3674
# 25    11125   3720
# 26    21973   6337
# 27     8510   2929
# 28     4980   1876
# 29    12370   4370
# 30    85756  18744
# ..      ...    ...
# 73    20311   7527
# 74    74446  18238
# 75    52996  14549
# 76    48022  15133
# 77    43575  12761
# 78    46751  12884
# 79    47739  14337
# 80    61473  16987
# 81    46927  13456
# 82    46709  13450
# 83    43445  12478
# 84    45182  12622
# 85    54151  15871
# 86    45461  13180
# 87    41175  12316
# 88    50751  14779
# 89    48889  14395
# 90   134382  30728
# 91   130834  27834
# 92   109270  26786
# 93    65225  19230
# 94    52982  16648
# 95    98218  25353
# 96    77627  21399
# 97    44293  13898
# 98   128630  29300
# 99    21440   7836
# 100  107303  27644
# 101  195771  40665
# 102   30567   9700
#
# [102 rows x 5 columns]
#   language       author                      title length unique
# 1  English  Shakespeare  A Midsummer Night's Dream  16103   4345
# 2  English  Shakespeare                     Hamlet  28551   6776
# 3  English  Shakespeare                    Macbeth  16874   4780
# 4  English  Shakespeare                    Othello  26590   5898
# 5  English  Shakespeare                Richard III  48315   5449
#        language       author                   title  length unique
# 98   Portuguese      Queir¢s  O crime do padre Amaro  128630  29300
# 99   Portuguese      Queir¢s              O Mandarim   21440   7836
# 100  Portuguese      Queir¢s         O Primo Bazilio  107303  27644
# 101  Portuguese      Queir¢s                Os Maias  195771  40665
# 102  Portuguese  Shakespeare                  Hamlet   30567   9700
#     name age
# 1  James  22
# 2   Jess  32
# Index(['name', 'age'], dtype='object')

# %%
plt.loglog(stats.length, stats.unique,"bo")

# %%
plt.plot(stats.length, stats.unique,"bo")

# %%
plt.loglog(stats.length, stats.unique,"bo")

# %%
# %matplotlib inline

# %%
ix = birddata.bird_name =="Eric"
x, y = birddata.longitude[ix], birddata.latitude[ix]

plt.figure(figsize = (7,7))

plt.plot(x,y,".")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-1907ef4e8270> in <module>()
# ----> 1 ix = birddata.bird_name =="Eric"
#       2 x, y = birddata.longitude[ix], birddata.latitude[ix]
#       3
#       4 plt.figure(figsize = (7,7))
#       5
#
# NameError: name 'birddata' is not defined

# %%
ix = birddata.bird_name =="Eric"
x, y = birddata.longitude[ix], birddata.latitude[ix]

plt.figure(figsize = (7,7))

plt.plot(x,y,".")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-1907ef4e8270> in <module>()
# ----> 1 ix = birddata.bird_name =="Eric"
#       2 x, y = birddata.longitude[ix], birddata.latitude[ix]
#       3
#       4 plt.figure(figsize = (7,7))
#       5
#
# NameError: name 'birddata' is not defined

# %%
'''
2.1 Learn how GPS data can be used to track bird migration patterns
'''

'''
track 3 birds, csv file contain latitude, longtitude, altitude and time stamps
'''

import pandas as pd  
#read csv file
birddata = pd.read_csv("/Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_4/bird_tracking.csv")

birddata.info()

print(birddata.head())

'''
2.2 Learn how to plot latitude and longitude on a simple 2D plot
'''
import matplotlib.pyplot as plt
import numpy as np  

ix = birddata.bird_name =="Eric"
x, y = birddata.longitude[ix], birddata.latitude[ix]

plt.figure(figsize = (7,7))

plt.plot(x,y,".")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61920 entries, 0 to 61919
# Data columns (total 8 columns):
# altitude              61920 non-null int64
# date_time             61920 non-null object
# device_info_serial    61920 non-null int64
# direction             61477 non-null float64
# latitude              61920 non-null float64
# longitude             61920 non-null float64
# speed_2d              61477 non-null float64
# bird_name             61920 non-null object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 3.8+ MB
#    altitude               date_time  device_info_serial   direction  \
# 0        71  2013-08-15 00:18:08+00                 851 -150.469753
# 1        68  2013-08-15 00:48:07+00                 851 -136.151141
# 2        68  2013-08-15 01:17:58+00                 851  160.797477
# 3        73  2013-08-15 01:47:51+00                 851   32.769360
# 4        69  2013-08-15 02:17:42+00                 851   45.191230
#
#     latitude  longitude  speed_2d bird_name
# 0  49.419859   2.120733  0.150000      Eric
# 1  49.419880   2.120746  2.438360      Eric
# 2  49.420310   2.120885  0.596657      Eric
# 3  49.420359   2.120859  0.310161      Eric
# 4  49.420331   2.120887  0.193132      Eric

# %%
'''
2.1 Learn how GPS data can be used to track bird migration patterns
'''

'''
track 3 birds, csv file contain latitude, longtitude, altitude and time stamps
'''

import pandas as pd  
#read csv file
birddata = pd.read_csv("/Users/tp10/Sanger_work/Developer101/python_for_research_edXcourse/Week_4/bird_tracking.csv")

birddata.info()

print(birddata.head())

'''
2.2 Learn how to plot latitude and longitude on a simple 2D plot
'''
import matplotlib.pyplot as plt
import numpy as np  

ix = birddata.bird_name =="Eric"
x, y = birddata.longitude[ix], birddata.latitude[ix]

plt.figure(figsize = (7,7))

plt.plot(x,y,".")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61920 entries, 0 to 61919
# Data columns (total 8 columns):
# altitude              61920 non-null int64
# date_time             61920 non-null object
# device_info_serial    61920 non-null int64
# direction             61477 non-null float64
# latitude              61920 non-null float64
# longitude             61920 non-null float64
# speed_2d              61477 non-null float64
# bird_name             61920 non-null object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 3.8+ MB
#    altitude               date_time  device_info_serial   direction  \
# 0        71  2013-08-15 00:18:08+00                 851 -150.469753
# 1        68  2013-08-15 00:48:07+00                 851 -136.151141
# 2        68  2013-08-15 01:17:58+00                 851  160.797477
# 3        73  2013-08-15 01:47:51+00                 851   32.769360
# 4        69  2013-08-15 02:17:42+00                 851   45.191230
#
#     latitude  longitude  speed_2d bird_name
# 0  49.419859   2.120733  0.150000      Eric
# 1  49.419880   2.120746  2.438360      Eric
# 2  49.420310   2.120885  0.596657      Eric
# 3  49.420359   2.120859  0.310161      Eric
# 4  49.420331   2.120887  0.193132      Eric
